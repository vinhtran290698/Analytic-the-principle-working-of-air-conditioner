# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
#plt.style.use('fivethirtyeight')

# %% [markdown]
# # 20 độ C

# %% [markdown]
# ## Inverter

# %%
data_inv_20_khaosat = pd.read_csv(r'D:\HỌC TẬP\ĐỒ ÁN TỐT NGHIỆP\24.5.2021\20 inv.csv')

# %%
data_inv_20_khaosat.set_index('Time',inplace=True)

# %%
data_inv_20_khaosat
data_inv_20_khaosat.describe().transpose()
# Out:
#        count        mean         std  min         25%         50%         75%  \
# I(A)    60.0    3.520499    0.472282  0.0    3.578456    3.596837    3.609250
# P(W)    60.0  774.509773  103.902052  0.0  787.260425  791.304200  794.035075
# E(Wh)   60.0  386.282576  230.131617  0.0  191.751018  386.594976  580.863197
#
#               max
# I(A)     3.630744
# P(W)   798.763700
# E(Wh)  774.509773

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_20_khaosat['I(A)'].values,linewidth=3,label='Dòng điện tức thời (A)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,4.5,0.5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('I(A)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_20_khaosat['P(W)'].values,linewidth=3,label='Công suất tác dụng (W)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,1000,100),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_20_khaosat['E(Wh)'].values,linewidth=3,label='Điện năng tiêu thụ (Wh)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,800,100),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_20_khaosat['E(Wh)'].diff(1).values,linewidth=3,marker='o',
        markerfacecolor='red',markersize=7,label='Điện năng tiêu thụ tăng trong mỗi phút (Wh)')
plt.xticks(np.arange(0,70,10),size=15)
plt.yticks(np.arange(0,20,5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()
data_inv_20_khaosat['E(Wh)'].diff(1)
# Out:
# Time
# 21/05/2021 21:41:34          NaN
# 21/05/2021 21:42:34    10.518193
# 21/05/2021 21:43:34    12.822727
# 21/05/2021 21:44:34    12.974443
# 21/05/2021 21:45:34    13.196528
# 21/05/2021 21:46:34    13.295693
# 21/05/2021 21:47:34    13.205555
# 21/05/2021 21:48:34    13.205140
# 21/05/2021 21:49:34    13.248183
# 21/05/2021 21:50:34    13.288750
# 21/05/2021 21:51:34    13.188473
# 21/05/2021 21:52:34    13.181390
# 21/05/2021 21:53:34    13.202500
# 21/05/2021 21:54:34    13.300695
# 21/05/2021 21:55:34    13.230455
# 21/05/2021 21:56:34    13.189722
# 21/05/2021 21:57:34    13.272915
# 21/05/2021 21:58:34    13.280000
# 21/05/2021 21:59:34    13.293332
# 21/05/2021 22:00:34    13.167917
# 21/05/2021 22:01:34    13.147727
# 21/05/2021 22:02:34    13.215278
# 21/05/2021 22:03:34    13.192223
# 21/05/2021 22:04:34    13.154305
# 21/05/2021 22:05:34    13.218890
# 21/05/2021 22:06:34    13.151943
# 21/05/2021 22:07:34    13.217273
# 21/05/2021 22:08:34    13.269445
# ...

# %% [markdown]
# ## Non-Inverter

# %%
data_mono_20_khaosat = pd.read_csv(r'D:\HỌC TẬP\ĐỒ ÁN TỐT NGHIỆP\24.5.2021\20 mono.csv')
data_mono_20_khaosat
# Out:
#                    Time      I(A)      P(W)       E(Wh)
# 0   21/05/2021 21:51:17  0.000000    0.0000    0.000000
# 1   21/05/2021 21:52:17  1.590909  350.0000    5.833333
# 2   21/05/2021 21:53:17  2.982614  656.1750   16.769583
# 3   21/05/2021 21:54:17  3.155720  694.2583   28.340555
# 4   21/05/2021 21:55:17  3.234835  711.6636   40.201615
# 5   21/05/2021 21:56:17  3.286970  723.1334   52.253838
# 6   21/05/2021 21:57:17  3.312576  728.7667   64.399950
# 7   21/05/2021 21:58:17  3.322424  730.9333   76.582172
# 8   21/05/2021 21:59:17  3.332765  733.2083   88.802310
# 9   21/05/2021 22:00:17  3.352614  737.5750  101.095227
# 10  21/05/2021 22:01:17  3.364876  740.2727  113.433105
# 11  21/05/2021 22:02:17  3.377614  743.0751  125.817690
# 12  21/05/2021 22:03:17  3.391629  746.1584  138.253663
# 13  21/05/2021 22:04:17  3.392690  746.3917  150.693525
# 14  21/05/2021 22:05:17  3.405758  749.2667  163.181303
# 15  21/05/2021 22:06:17  3.403788  748.8334  175.661860
# ...

# %%
data_mono_20_khaosat.describe().transpose()
# Out:
#        count        mean         std  min         25%         50%         75%  \
# I(A)    60.0    3.332205    0.504135  0.0    3.405265    3.451666    3.460360
# P(W)    60.0  733.085183  110.909805  0.0  749.158375  759.366600  761.279150
# E(Wh)   60.0  360.062115  219.940031  0.0  172.541721  359.122502  546.217687
#
#               max
# I(A)     3.495992
# P(W)   769.118200
# E(Wh)  733.085183

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_20_khaosat['I(A)'].values,linewidth=3,label='Dòng điện tức thời (A)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,4,0.5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('I(A)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_20_khaosat['P(W)'].values,linewidth=3,label='Công suất tác dụng (W)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,900,100),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_20_khaosat['E(Wh)'].values,linewidth=3,label='Điện năng tiêu thụ (Wh)',
         marker='o',markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,900,100),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_20_khaosat['E(Wh)'].diff(1).values,linewidth=3,marker='o',
        markerfacecolor='red',markersize=7,label='Điện năng tiêu thụ tăng trong mỗi phút (Wh)')
plt.xticks(np.arange(0,70,10),size=15)
plt.yticks(np.arange(0,20,5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()
data_mono_20_khaosat['E(Wh)'].diff(1)
# Out:
# 0           NaN
# 1      5.833333
# 2     10.936250
# 3     11.570972
# 4     11.861060
# 5     12.052223
# 6     12.146112
# 7     12.182222
# 8     12.220138
# 9     12.292917
# 10    12.337878
# 11    12.384585
# 12    12.435973
# 13    12.439862
# 14    12.487778
# 15    12.480557
# 16    12.540152
# 17    12.589723
# 18    12.566250
# 19    12.582083
# 20    12.652362
# 21    12.678333
# 22    12.705972
# 23    12.694862
# 24    12.659167
# 25    12.689443
# 26    12.674862
# 27    12.685908
# 28    12.706805
# 29    12.707638
# 30    12.654165
# 31    12.638890
# 32    12.646667
# 33    12.679090
# 34    12.712222
# 35    12.658473
# 36    12.611943
# 37    12.675833
# 38    12.694583
# 39    12.740303
# 40    12.725278
# 41    12.690695
# 42    12.659723
# 43    12.749583
# 44    12.720303
# 45    12.658055
# 46    12.605557
# 47    12.620833
# 48    12.670417
# 49    12.705833
# 50    12.670455
# 51    12.642917
# 52    12.609862
# 53    12.664862
# 54    12.687500
# ...

# %% [markdown]
# ## So sánh

# %% [markdown]
# ### Dòng điện

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_20_khaosat['I(A)'].values, linewidth=3, color='blue',
         marker='o',markerfacecolor='red',markersize=7, label='Dòng điện máy lạnh Inverter (A)')

plt.plot(data_mono_20_khaosat['I(A)'].values, linewidth=3, color='orange',
         marker='o',markerfacecolor='black',markersize=7, label='Dòng điện máy lạnh Non-Inverter (A)')

plt.yticks(np.arange(0,4.5,0.5),fontsize=15)
plt.xticks(np.arange(0,65,5),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('I(A)',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ### Công suất

# %%
plt.figure(figsize=(10,5))
plt.plot(data_inv_20_khaosat['P(W)'].values, linewidth=3, color='blue',
         marker='o',markerfacecolor='red',markersize=7, label='Công suất tác dụng máy lạnh Inverter (W)')

plt.plot(data_mono_20_khaosat['P(W)'].values, linewidth=3, color='orange',
         marker='o',markerfacecolor='black',markersize=7, label='Công suất tác dụng máy lạnh Non-Inverter (W)')

plt.yticks(np.arange(0,900,100),fontsize=15)
plt.xticks(np.arange(0,65,5),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.title('Nhiệt độ phòng cài đặt: 20 độ C',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ### Điện năng tiêu thụ

# %%
plt.figure(figsize=(10,5))
plt.plot(data_inv_20_khaosat['E(Wh)'].values,linewidth=3, color='blue',
         marker='o',markerfacecolor='red',markersize=7, label='Điện năng tiêu thụ máy lạnh Inverter (Wh)')

plt.plot(data_mono_20_khaosat['E(Wh)'].values, linewidth=3, color='orange',
         marker='o',markerfacecolor='black',markersize=7, label='Điện năng tiêu thụ máy lạnh Non-Inverter (Wh)')

plt.yticks(np.arange(0,800,100),fontsize=15)
plt.xticks(np.arange(0,65,5),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(data_inv_20_khaosat['E(Wh)'].diff(1).values,linewidth=3,marker='o', color='blue',
        markerfacecolor='red',markersize=7,label='Điện năng tiêu thụ mỗi phút máy lạnh Inverter (Wh)')
plt.plot(data_mono_20_khaosat['E(Wh)'].diff(1).values,linewidth=3,marker='o', color='orange',
        markerfacecolor='black',markersize=7,label='Điện năng tiêu thụ tăng mỗi phút máy lạnh Non-Inverter (Wh)')
plt.xticks(np.arange(0,70,10),size=15)
plt.yticks(np.arange(0,20,5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
print(data_inv_20_khaosat['E(Wh)'].diff(1).values[1:].mean())
print(data_mono_20_khaosat['E(Wh)'].diff(1).values[1:].mean())
# Out:
# 13.12728429322034
# 12.425172598305085

# %%
E_chenhlech_20 = (data_inv_20_khaosat['E(Wh)'].values - data_mono_20_khaosat['E(Wh)'].values)

time = np.arange(0,60,1)
plt.figure(figsize=(10,5))
#plt.bar(time, E_chenhlech_20,label='Delta E(Wh) = Einv - Enon-inv')
plt.plot(E_chenhlech_20,label='Delta E(Wh) = Einv - Enon-inv',linewidth=3,marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks(np.arange(0,61,5),fontsize=15)
plt.yticks(np.arange(0,60,10),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('Delta E(Wh)',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# # 23 độ C

# %% [markdown]
# ## Inverter

# %%
inv_23 = pd.read_csv(r'D:\HỌC TẬP\ĐỒ ÁN TỐT NGHIỆP\24.5.2021\23 inv.csv')

data_inv_23 = inv_23.iloc[:,1:5]
data_inv_23.columns = ['Time','I(A)','P(W)','E(Wh)']
data_inv_23.set_index('Time',inplace=True)
data_inv_23['I(A)'] = pd.to_numeric(data_inv_23['I(A)'])
data_inv_23['P(W)'] = pd.to_numeric(data_inv_23['P(W)'])
data_inv_23['E(Wh)'] = pd.to_numeric(data_inv_23['E(Wh)'])
data_inv_23.head(23)
# Out:
#                          I(A)      P(W)       E(Wh)
# Time
# 21/05/2021 19:48:04  0.000000    0.0000    0.000000
# 21/05/2021 19:49:04  0.000000    0.0000    0.000000
# 21/05/2021 19:50:04  0.000000    0.0000    0.000000
# 21/05/2021 19:51:04  0.000000    0.0000    0.000000
# 21/05/2021 19:52:04  0.000000    0.0000    0.000000
# 21/05/2021 19:53:04  2.639621  580.7167    9.678612
# 21/05/2021 19:54:04  3.433967  755.4727   22.269823
# 21/05/2021 19:55:04  3.553560  781.7833   35.299545
# 21/05/2021 19:56:04  3.611780  794.5916   48.542738
# 21/05/2021 19:57:04  3.572576  785.9667   61.642183
# 21/05/2021 19:58:04  3.530303  776.6667   74.586628
# 21/05/2021 19:59:04  3.437121  756.1667   87.189407
# 21/05/2021 20:00:04  3.503512  770.7727  100.035618
# 21/05/2021 20:01:04  3.447879  758.5334  112.677842
# 21/05/2021 20:02:04  3.451174  759.2583  125.332147
# 21/05/2021 20:03:04  3.399508  747.8917  137.797008
# 21/05/2021 20:04:04  3.392424  746.3333  150.235897
# ...

# %%
data_inv_23_khaosat = data_inv_23['21/05/2021 19:52:04':'21/05/2021 20:51:04']
data_inv_23_khaosat.describe().transpose()
# Out:
#        count        mean         std  min         25%         50%         75%  \
# I(A)    60.0    2.880671    0.858352  0.0    2.188476    3.407879    3.616269
# P(W)    60.0  619.580927  175.187921  0.0  481.464625  747.112500  766.048025
# E(Wh)   60.0  343.812921  187.189832  0.0  184.877442  374.464595  502.430197
#
#               max
# I(A)     3.966611
# P(W)   799.841600
# E(Wh)  619.580927

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_23_khaosat['I(A)'].values,linewidth=3,label='Dòng điện tức thời (A)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,5.5,0.5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('I(A)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_23_khaosat['P(W)'].values,linewidth=3,label='Công suất tác dụng (W)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,1100,100),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_23_khaosat['E(Wh)'].values,linewidth=3,label='Điện năng tiêu thụ (Wh)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,800,100),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_23_khaosat['E(Wh)'].diff(1).values,linewidth=3,marker='o',
        markerfacecolor='red',markersize=7,label='Điện năng tiêu thụ tăng trong mỗi phút (Wh)')
plt.xticks(np.arange(0,70,10),size=15)
plt.yticks(np.arange(0,25,5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ## Non-Inverter

# %%
mono_23 = pd.read_csv(r'D:\HỌC TẬP\ĐỒ ÁN TỐT NGHIỆP\24.5.2021\23 mono.csv')
data_mono_23 = mono_23.iloc[2:,0:4]
data_mono_23.columns = ['Time','I(A)','P(W)','E(kWh)']
data_mono_23.set_index('Time',inplace=True)
data_mono_23['I(A)'] = pd.to_numeric(data_mono_23['I(A)'])
data_mono_23['P(W)'] = pd.to_numeric(data_mono_23['P(W)'])
data_mono_23['E(kWh)'] = pd.to_numeric(data_mono_23['E(kWh)'])
data_mono_23.head(23)
# Out:
#                          I(A)        P(W)  E(kWh)
# Time
# 21/05/2021 19:55:25  0.000000    2.990909   0.000
# 21/05/2021 19:56:25  0.000000    2.990909   0.000
# 21/05/2021 19:57:25  0.000000    3.008333   0.000
# 21/05/2021 19:58:25  0.000000    3.008333   0.000
# 21/05/2021 19:59:25  0.000000    3.016667   0.000
# 21/05/2021 20:00:25  0.000000    3.015384   0.000
# 21/05/2021 20:01:25  0.000000    3.008333   0.000
# 21/05/2021 20:02:25  0.471818  105.327300   0.001
# 21/05/2021 20:03:25  3.239167  707.525100   0.013
# 21/05/2021 20:04:25  3.159167  688.933300   0.025
# 21/05/2021 20:05:25  3.169167  691.258400   0.037
# 21/05/2021 20:06:25  3.165833  690.950000   0.048
# 21/05/2021 20:07:25  3.105000  677.066700   0.060
# 21/05/2021 20:08:25  3.132728  682.536400   0.071
# 21/05/2021 20:09:25  3.135834  683.741700   0.082
# 21/05/2021 20:10:25  3.162500  690.708300   0.094
# 21/05/2021 20:11:25  3.135000  685.383300   0.105
# 21/05/2021 20:12:25  3.132500  683.700000   0.117
# ...

# %%
data_mono_23_khaosat = data_mono_23['21/05/2021 20:01:25':'21/05/2021 21:00:25']
data_mono_23_khaosat.describe().transpose()
# Out:
#         count        mean         std       min         25%         50%  \
# I(A)     60.0    2.983777    0.520106  0.000000    3.035227    3.072197
# P(W)     60.0  651.842901  113.181762  3.008333  660.635400  672.889400
# E(kWh)   60.0    0.325367    0.196258  0.000000    0.159000    0.327000
#
#                75%         max
# I(A)      3.123087    3.239167
# P(W)    682.140325  707.525100
# E(kWh)    0.491750    0.653000

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_23_khaosat['I(A)'].values,linewidth=3,label='Dòng điện tức thời (A)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,5.5,0.5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('I(A)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_23_khaosat['P(W)'].values,linewidth=3,label='Công suất tác dụng (W)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,1100,100),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_23_khaosat['E(kWh)'].values*1000,linewidth=3,label='Điện năng tiêu thụ (Wh)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,800,100),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_23_khaosat['E(kWh)'].diff(1).values*1000,linewidth=3,marker='o',
        markerfacecolor='red',markersize=7,label='Điện năng tiêu thụ tăng trong mỗi phút (Wh)')
plt.xticks(np.arange(0,70,10),size=15)
plt.yticks(np.arange(0,20,5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ## So sánh

# %% [markdown]
# ### Dòng điện

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_23_khaosat['I(A)'].values, linewidth=3, color='blue',
         marker='o',markerfacecolor='red',markersize=7, label='Dòng điện máy lạnh Inverter (A)')

plt.plot(data_mono_23_khaosat['I(A)'].values, linewidth=3, color='orange',
         marker='o',markerfacecolor='black',markersize=7, label='Dòng điện máy lạnh Non-Inverter (A)')

plt.yticks(np.arange(0,5,0.5),fontsize=15)
plt.xticks(np.arange(0,65,5),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('I(A)',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ### Công suất

# %%
plt.figure(figsize=(10,5))
plt.plot(data_inv_23_khaosat['P(W)'].values, linewidth=3, color='blue',
         marker='o',markerfacecolor='red',markersize=7, label='Công suất tác dụng máy lạnh Inverter (W)')

plt.plot(data_mono_23_khaosat['P(W)'].values, linewidth=3, color='orange',
         marker='o',markerfacecolor='black',markersize=7, label='Công suất tác dụng máy lạnh Non-Inverter (W)')

plt.yticks(np.arange(0,1000,100),fontsize=15)
plt.xticks(np.arange(0,65,5),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ### Điện năng tiêu thụ

# %%
plt.figure(figsize=(10,5))
plt.plot(data_inv_23_khaosat['E(Wh)'].values, linewidth=3, color='blue',
         marker='o',markerfacecolor='red',markersize=7, label='Điện năng tiêu thụ máy lạnh Inverter (Wh)')

plt.plot(data_mono_23_khaosat['E(kWh)'].values*1000, linewidth=3, color='orange',
         marker='o',markerfacecolor='black',markersize=7, label='Điện năng tiêu thụ máy lạnh Non-Inverter (Wh)')

plt.yticks(np.arange(0,800,100),fontsize=15)
plt.xticks(np.arange(0,65,5),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(data_inv_23_khaosat['E(Wh)'].diff(1).values,linewidth=3,marker='o', color='blue',
        markerfacecolor='red',markersize=7,label='Điện năng tiêu thụ mỗi phút máy lạnh Inverter (Wh)')
plt.plot(data_mono_23_khaosat['E(kWh)'].diff(1).values*1000,linewidth=3,marker='o', color='orange',
        markerfacecolor='black',markersize=7,label='Điện năng tiêu thụ mỗi phút máy lạnh Non-Inverter (Wh)')
plt.xticks(np.arange(0,70,10),size=15)
plt.yticks(np.arange(0,20,5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
print(data_inv_23_khaosat['E(Wh)'].diff(1).values[1:].mean())
print(data_mono_23_khaosat['E(kWh)'].diff(1).values[1:].mean())
# Out:
# 10.501371638983052
# 0.011067796610169493

# %%
E_chenhlech_23 = (data_inv_23_khaosat['E(Wh)'].values - data_mono_23_khaosat['E(kWh)'].values*1000)

time = np.arange(0,60,1)
plt.figure(figsize=(10,5))
#plt.bar(time, E_chenhlech_23,label='Delta E(Wh) = Einv - Enon-inv')
plt.plot(E_chenhlech_23,label='Delta E(Wh) = Einv - Enon-inv',linewidth=3,marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks(np.arange(0,61,5),fontsize=15)
plt.yticks(np.arange(-50,90,10),fontsize=15)
plt.axhline(y=0,color='black',linewidth=3)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('Delta E(Wh)',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# # 25 độ C

# %% [markdown]
# ## Inverter

# %%
inv_25 = pd.read_csv(r'D:\HỌC TẬP\ĐỒ ÁN TỐT NGHIỆP\24.5.2021\25 inv.csv')
data_inv_25 = inv_25.iloc[2:,0:4]
data_inv_25.columns = ['Time','I(A)','P(W)','E(kWh)']
data_inv_25.set_index('Time',inplace=True)
data_inv_25['I(A)'] = pd.to_numeric(data_inv_25['I(A)'])
data_inv_25['P(W)'] = pd.to_numeric(data_inv_25['P(W)'])
data_inv_25['E(kWh)'] = pd.to_numeric(data_inv_25['E(kWh)'])
data_inv_25.head(25)
# Out:
#                          I(A)      P(W)  E(kWh)
# Time
# 22/05/2021 01:15:15  0.000000    0.0000   0.000
# 22/05/2021 01:16:16  0.000000    0.0000   0.000
# 22/05/2021 01:17:15  0.138333   17.5500   0.000
# 22/05/2021 01:18:16  2.980000  622.3667   0.010
# 22/05/2021 01:19:16  3.140909  665.9091   0.021
# 22/05/2021 01:20:16  3.259167  691.2000   0.032
# 22/05/2021 01:21:16  3.315833  703.1917   0.045
# 22/05/2021 01:22:16  3.359167  712.2499   0.057
# 22/05/2021 01:23:16  3.350833  711.0833   0.069
# 22/05/2021 01:24:16  3.341666  710.0083   0.082
# 22/05/2021 01:25:16  3.366364  714.5546   0.093
# 22/05/2021 01:26:16  3.377500  714.9750   0.105
# 22/05/2021 01:27:16  3.394167  718.4333   0.118
# 22/05/2021 01:28:16  3.391667  717.1084   0.130
# 22/05/2021 01:29:16  3.411667  721.3750   0.142
# 22/05/2021 01:30:16  3.405000  720.0500   0.155
# 22/05/2021 01:31:16  3.389091  716.8364   0.166
# 22/05/2021 01:32:16  3.358333  713.5167   0.179
# ...

# %%
data_inv_25_khaosat = data_inv_25['22/05/2021 01:17:15':'22/05/2021 02:17:15']
data_inv_25_khaosat.describe().transpose()
# Out:
#         count        mean         std        min         25%         50%  \
# I(A)     60.0    2.467172    0.621956   0.138333    2.030473    2.147917
# P(W)     60.0  406.597045  180.345094  17.550000  288.271625  313.220800
# E(kWh)   60.0    0.243500    0.114260   0.000000    0.175750    0.262000
#
#               75%         max
# I(A)      2.80750    3.411667
# P(W)    450.12290  721.375000
# E(kWh)    0.33525    0.414000

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_25_khaosat['I(A)'].values,linewidth=3,label='Dòng điện tức thời (A)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks(np.arange(0,130,10),size=15)
plt.yticks(np.arange(0,4.5,0.5),size=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('I(A)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_25_khaosat['P(W)'].values,linewidth=3,label='Công suất tác dụng (W)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks(np.arange(0,130,10),size=15)
plt.yticks(np.arange(0,850,100),size=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_25_khaosat['E(kWh)'].values*1000,linewidth=3,label='Điện năng tiêu thụ (Wh)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks(np.arange(0,130,10),size=15)
plt.yticks(np.arange(0,900,100),size=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_25_khaosat['E(kWh)'].diff(1).values*1000,linewidth=3,marker='o',
        markerfacecolor='red',markersize=7,label='Điện năng tiêu thụ sai khác mỗi phút (Wh)')
plt.xticks(np.arange(0,130,10),size=15)
plt.yticks(np.arange(0,20,5),size=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ## Non-Inverter

# %%
mono_25 = pd.read_csv(r'D:\HỌC TẬP\ĐỒ ÁN TỐT NGHIỆP\24.5.2021\25 mono.csv')
data_mono_25 = mono_25.iloc[2:,0:4]
data_mono_25.columns = ['Time','I(A)','P(W)','E(kWh)']
data_mono_25.set_index('Time',inplace=True)
data_mono_25['I(A)'] = pd.to_numeric(data_mono_25['I(A)'])
data_mono_25['P(W)'] = pd.to_numeric(data_mono_25['P(W)'])
data_mono_25['E(kWh)'] = pd.to_numeric(data_mono_25['E(kWh)'])
data_mono_25.head(25)
# Out:
#                          I(A)       P(W)  E(kWh)
# Time
# 22/05/2021 01:27:48  0.000000    0.00000   0.000
# 22/05/2021 01:28:48  0.000000    0.00000   0.000
# 22/05/2021 01:29:48  0.000000    0.00000   0.000
# 22/05/2021 01:30:48  1.173333  255.58330   0.004
# 22/05/2021 01:31:48  2.740833  598.52500   0.014
# 22/05/2021 01:32:48  2.742727  598.09090   0.023
# 22/05/2021 01:33:48  2.784167  607.84170   0.034
# 22/05/2021 01:34:48  2.807500  612.19170   0.044
# 22/05/2021 01:35:48  2.835833  619.15000   0.054
# 22/05/2021 01:36:48  2.842500  620.59170   0.065
# 22/05/2021 01:37:48  2.854167  623.61660   0.075
# 22/05/2021 01:38:48  2.888182  630.48180   0.085
# 22/05/2021 01:39:48  2.900833  632.00840   0.096
# 22/05/2021 01:40:48  2.907500  633.22500   0.107
# 22/05/2021 01:41:48  2.910833  633.64170   0.117
# 22/05/2021 01:42:48  2.930000  637.62510   0.128
# 22/05/2021 01:43:48  2.928182  637.64540   0.138
# 22/05/2021 01:44:48  2.938333  640.06670   0.149
# ...

# %%
data_mono_25_khaosat = data_mono_25['22/05/2021 01:29:48':'22/05/2021 02:29:48']
data_mono_25_khaosat.describe().transpose()
# Out:
#         count        mean         std  min         25%         50%       75%  \
# I(A)     61.0    2.163387    1.177423  0.0    1.173333    2.910833    2.9625
# P(W)     61.0  469.137561  260.416771  0.0  255.583300  633.641700  645.8636
# E(kWh)   61.0    0.245361    0.136984  0.0    0.149000    0.248000    0.3570
#
#                max
# I(A)      2.992727
# P(W)    652.649900
# E(kWh)    0.477000

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_25_khaosat['I(A)'].values,linewidth=3,label='Dòng điện tức thời (A)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks(np.arange(0,130,10),size=15)
plt.yticks(np.arange(0,3.5,0.5),size=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('I(A)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_25_khaosat['P(W)'].values,linewidth=3,label='Công suất tác dụng (W)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks(np.arange(0,130,10),size=15)
plt.yticks(np.arange(0,750,100),size=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_25_khaosat['E(kWh)'].values*1000,linewidth=3,label='Điện năng tiêu thụ (Wh)',
         marker='o',markerfacecolor='red',markersize=7)
plt.xticks(np.arange(0,130,10),size=15)
plt.yticks(np.arange(0,1000,100),size=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_25_khaosat['E(kWh)'].diff(1).values*1000,linewidth=3,marker='o',
        markerfacecolor='red',markersize=7,label='Điện năng tiêu thụ sai khác mỗi phút (Wh)')
plt.xticks(np.arange(0,130,10),size=15)
plt.yticks(np.arange(0,20,5),size=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ## So sánh

# %% [markdown]
# ### Dòng điện

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_25_khaosat['I(A)'].values, linewidth=3, color='blue',
         marker='o',markerfacecolor='red',markersize=7, label='Dòng điện máy lạnh Inverter (A)')

plt.plot(data_mono_25_khaosat['I(A)'].values, linewidth=3, color='orange',
         marker='o',markerfacecolor='black',markersize=7, label='Dòng điện máy lạnh Non-Inverter (A)')

plt.yticks(np.arange(0,4,0.5),fontsize=15)
plt.xticks(np.arange(0,130,10),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('I(A)',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ### Công suất

# %%
plt.figure(figsize=(10,5))
plt.plot(data_inv_25_khaosat['P(W)'].values, linewidth=3, color='blue',
         marker='o',markerfacecolor='red',markersize=7, label='Công suất tác dụng máy lạnh Inverter (W)')

plt.plot(data_mono_25_khaosat['P(W)'].values, linewidth=3, color='orange',
         marker='o',markerfacecolor='black',markersize=7, label='Công suất tác dụng máy lạnh Non-Inverter (W)')

plt.yticks(np.arange(0,850,100),fontsize=15)
plt.xticks(np.arange(0,130,10),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ### Điện năng tiêu thụ

# %%
plt.figure(figsize=(10,5))
plt.plot(data_inv_25_khaosat['E(kWh)'].values*1000, linewidth=3, color='blue',
         marker='o',markerfacecolor='red',markersize=7, label='Điện năng tiêu thụ máy lạnh Inverter (Wh)')

plt.plot(data_mono_25_khaosat['E(kWh)'].values*1000, linewidth=3, color='orange',
         marker='o',markerfacecolor='black',markersize=7, label='Điện năng tiêu thụ máy lạnh Non-Inverter (Wh)')

plt.yticks(np.arange(0,1000,100),fontsize=15)
plt.xticks(np.arange(0,130,10),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(data_inv_25_khaosat['E(kWh)'].diff(1).values*1000,linewidth=3,marker='o', color='blue',
        markerfacecolor='red',markersize=7,label='Điện năng tiêu thụ tăng trong mỗi phút máy lạnh Inverter (Wh)')
plt.plot(data_mono_25_khaosat['E(kWh)'].diff(1).values*1000,linewidth=3,marker='o', color='orange',
        markerfacecolor='black',markersize=7,label='Điện năng tiêu thụ tăng trong mỗi phút máy lạnh Non-Inverter (Wh)')
plt.xticks(np.arange(0,130,10),size=15)
plt.yticks(np.arange(0,20,5),size=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
print(data_inv_25_khaosat['E(kWh)'].diff(1).values[1:].mean())
print(data_mono_25_khaosat['E(kWh)'].diff(1).values[1:].mean())
# Out:
# 0.007016949152542373
# 0.00795

# %%
E_chenhlech_25 = (data_inv_25_khaosat['E(kWh)'].values - data_mono_25_khaosat['E(kWh)'].values[1:])*1000

time = np.arange(0,60,1)
plt.figure(figsize=(10,5))
plt.plot(E_chenhlech_25,label='Delta E(Wh) = Einv - Enon-inv',linewidth=3,marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks(np.arange(0,130,10),fontsize=15)
plt.yticks(np.arange(-140,65,25),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('Delta E(Wh)',fontsize=15)
plt.axhline(y=0,color='black',linewidth=3)
plt.grid()
plt.show()

# %% [markdown]
# # 27 độ C

# %% [markdown]
# ## Inverter

# %%
inv_27 = pd.read_csv(r'D:\HỌC TẬP\ĐỒ ÁN TỐT NGHIỆP\24.5.2021\27 inv.csv')
data_inv_27 = inv_27.iloc[2:,0:4]
data_inv_27.columns = ['Time','I(A)','P(W)','E(kWh)']
data_inv_27.set_index('Time',inplace=True)
data_inv_27['I(A)'] = pd.to_numeric(data_inv_27['I(A)'])
data_inv_27['P(W)'] = pd.to_numeric(data_inv_27['P(W)'])
data_inv_27['E(kWh)'] = pd.to_numeric(data_inv_27['E(kWh)'])
data_inv_27.head(27)
# Out:
#                          I(A)        P(W)  E(kWh)
# Time
# 21/05/2021 14:10:39  0.000000    0.000000   0.000
# 21/05/2021 14:11:39  0.044167    1.008333   0.000
# 21/05/2021 14:12:39  0.260000    3.075000   0.000
# 21/05/2021 14:13:39  0.260000    2.766667   0.000
# 21/05/2021 14:14:39  0.240000    2.472727   0.000
# 21/05/2021 14:15:39  1.275833  243.900000   0.004
# 21/05/2021 14:16:39  3.066667  656.241600   0.015
# 21/05/2021 14:17:39  3.280000  698.216700   0.027
# 21/05/2021 14:18:39  3.404166  715.775000   0.040
# 21/05/2021 14:19:39  3.419167  720.583300   0.052
# 21/05/2021 14:20:39  2.999091  633.499900   0.062
# 21/05/2021 14:21:39  0.318333   54.575000   0.063
# 21/05/2021 14:22:39  0.234167   32.091660   0.064
# 21/05/2021 14:23:39  0.233333   32.591670   0.064
# 21/05/2021 14:24:39  0.235000   32.375000   0.065
# 21/05/2021 14:25:39  0.230909   31.672730   0.065
# 21/05/2021 14:26:39  0.235000   32.675000   0.066
# 21/05/2021 14:27:39  0.234167   32.050000   0.067
# ...

# %%
data_inv_27_khaosat = data_inv_27['21/05/2021 14:14:39':'21/05/2021 15:13:39']
data_inv_27_khaosat.describe().transpose()
# Out:
#         count        mean         std       min        25%        50%  \
# I(A)     60.0    0.872292    1.087895  0.230909   0.234167   0.236667
# P(W)     60.0  155.411931  224.594079  2.472727  31.720833  32.195835
# E(kWh)   60.0    0.098633    0.041910  0.000000   0.067750   0.109500
#
#                75%         max
# I(A)      1.333011    3.486666
# P(W)    230.127300  727.225100
# E(kWh)    0.126000    0.159000

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_27_khaosat['I(A)'].values,linewidth=3,label='Dòng điện tức thời (A)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,4,0.5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('I(A)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_27_khaosat['P(W)'].values,linewidth=3,label='Công suất tác dụng (W)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,850,100),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_27_khaosat['E(kWh)'].values*1000,linewidth=3,label='Điện năng tiêu thụ (Wh)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,200,25),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_27_khaosat['E(kWh)'].diff(1).values*1000,linewidth=3,marker='o',
        markerfacecolor='red',markersize=7,label='Điện năng tiêu thụ mỗi phút (Wh)')
plt.xticks(np.arange(0,70,10),size=15)
plt.yticks(np.arange(0,20,5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ## Non-Inverter

# %%
mono_27 = pd.read_csv(r'D:\HỌC TẬP\ĐỒ ÁN TỐT NGHIỆP\24.5.2021\27 mono.csv')
data_mono_27 = mono_27.iloc[2:,0:4]
data_mono_27.columns = ['Time','I(A)','P(W)','E(kWh)']
data_mono_27.set_index('Time',inplace=True)
data_mono_27['I(A)'] = pd.to_numeric(data_mono_27['I(A)'])
data_mono_27['P(W)'] = pd.to_numeric(data_mono_27['P(W)'])
data_mono_27['E(kWh)'] = pd.to_numeric(data_mono_27['E(kWh)'])
data_mono_27.head(27)
# Out:
#                          I(A)        P(W)  E(kWh)
# Time
# 21/05/2021 14:20:30  0.000000    0.000000   0.000
# 21/05/2021 14:21:30  0.000000    0.000000   0.000
# 21/05/2021 14:22:30  0.002500    2.166667   0.000
# 21/05/2021 14:23:30  0.940000  205.925000   0.003
# 21/05/2021 14:24:30  2.485000  542.208300   0.012
# 21/05/2021 14:25:30  2.687273  588.600000   0.021
# 21/05/2021 14:26:30  2.810833  607.066700   0.031
# 21/05/2021 14:27:30  1.080833  231.308300   0.035
# 21/05/2021 14:28:30  0.184167   37.475000   0.036
# 21/05/2021 14:29:30  0.185000   37.525000   0.037
# 21/05/2021 14:30:30  0.186667   37.600000   0.037
# 21/05/2021 14:31:30  0.181818   37.481820   0.038
# 21/05/2021 14:32:30  2.466667  527.333300   0.046
# 21/05/2021 14:33:30  2.934167  637.625000   0.057
# 21/05/2021 14:34:30  0.181667   37.650000   0.058
# 21/05/2021 14:35:30  0.180000   37.491670   0.059
# 21/05/2021 14:36:30  0.180000   37.425000   0.059
# 21/05/2021 14:37:30  0.180000   37.454540   0.060
# ...

# %%
data_mono_27_khaosat = data_mono_27['21/05/2021 14:22:30':'21/05/2021 15:21:30']
data_mono_27_khaosat.describe().transpose()
# Out:
#         count        mean         std       min       25%       50%  \
# I(A)     60.0    0.891996    1.065699  0.002500   0.18000   0.18000
# P(W)     60.0  191.272524  230.546727  2.166667  37.60000  37.73333
# E(kWh)   60.0    0.102600    0.051707  0.000000   0.05975   0.10350
#
#                75%         max
# I(A)      1.556667    3.076667
# P(W)    335.041700  662.033300
# E(kWh)    0.147000    0.190000

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_27_khaosat['I(A)'].values,linewidth=3,label='Dòng điện tức thời (A)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,3.5,0.5),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('I(A)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_27_khaosat['P(W)'].values,linewidth=3,label='Công suất tác dụng (W)',marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,750,100),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_27_khaosat['E(kWh)'].values*1000,linewidth=3,label='Điện năng tiêu thụ (Wh)',
         marker='o',markerfacecolor='red',markersize=7)
plt.xticks([0,10,20,30,40,50,60],size=15)
plt.yticks(np.arange(0,250,25),size=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(data_mono_27_khaosat['E(kWh)'].diff(1).values*1000,linewidth=3,marker='o',
        markerfacecolor='red',markersize=7,label='Điện năng tiêu thụ mỗi phút (Wh)')
plt.xticks(np.arange(0,70,10),size=15)
plt.yticks(np.arange(0,20,5),size=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ## So sánh

# %% [markdown]
# ### Dòng điện

# %%
plt.figure(figsize=(20,8))
plt.plot(data_inv_27_khaosat['I(A)'].values, linewidth=3, color='blue',
         marker='o',markerfacecolor='red',markersize=7, label='Dòng điện máy lạnh Inverter (A)')

plt.plot(data_mono_27_khaosat['I(A)'].values, linewidth=3, color='orange',
         marker='o',markerfacecolor='black',markersize=7, label='Dòng điện máy lạnh Non-Inverter (A)')

plt.yticks(np.arange(0,4,0.5),fontsize=15)
plt.xticks(np.arange(0,65,5),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('I(A)',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ### Công suất

# %%
plt.figure(figsize=(10,5))
plt.plot(data_inv_27_khaosat['P(W)'].values, linewidth=3, color='blue',
         marker='o',markerfacecolor='red',markersize=7, label='Công suất tác dụng máy lạnh Inverter (W)')

plt.plot(data_mono_27_khaosat['P(W)'].values, linewidth=3, color='orange',
         marker='o',markerfacecolor='black',markersize=7, label='Công suất tác dụng máy lạnh Non-Inverter (W)')

plt.yticks(np.arange(0,850,100),fontsize=15)
plt.xticks(np.arange(0,65,5),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.grid()
plt.show()

# %% [markdown]
# ### Điện năng tiêu thụ

# %%
plt.figure(figsize=(10,5))
plt.plot(data_inv_27_khaosat['E(kWh)'].values*1000, linewidth=3, color='blue',
         marker='o',markerfacecolor='red',markersize=7, label='Điện năng tiêu thụ máy lạnh Inverter (Wh)')

plt.plot(data_mono_27_khaosat['E(kWh)'].values*1000, linewidth=3, color='orange',
         marker='o',markerfacecolor='black',markersize=7, label='Điện năng tiêu thụ máy lạnh Non-Inverter (Wh)')

plt.yticks(np.arange(0,250,25),fontsize=15)
plt.xticks(np.arange(0,65,5),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.plot(data_inv_27_khaosat['E(kWh)'].diff(1).values*1000,linewidth=3,marker='o', color='blue',
        markerfacecolor='red',markersize=7,label='Điện năng tiêu thụ mỗi phút máy lạnh Inverter (Wh)')
plt.plot(data_mono_27_khaosat['E(kWh)'].diff(1).values*1000,linewidth=3,marker='o', color='orange',
        markerfacecolor='black',markersize=7,label='Điện năng tiêu thụ mỗi phút máy lạnh Non-Inverter (Wh)')
plt.xticks(np.arange(0,70,10),size=15)
plt.yticks(np.arange(0,20,5),size=15)
plt.xlabel('Thời gian khảo sát (120 phút)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.grid()
plt.show()

# %%
print(data_inv_27_khaosat['E(kWh)'].diff(1).values[1:].mean())
print(data_mono_27_khaosat['E(kWh)'].diff(1).values[1:].mean())
# Out:
# 0.0026949152542372883
# 0.0032203389830508474

# %%
E_chenhlech_27 = (data_inv_27_khaosat['E(kWh)'].values - data_mono_27_khaosat['E(kWh)'].values)*1000

time = np.arange(0,60,1)
plt.figure(figsize=(10,5))
#plt.bar(time, E_chenhlech_27,label='Delta E(Wh) = Einv - Enon-inv')
plt.plot(E_chenhlech_27,label='Delta E(Wh) = Einv - Enon-inv',linewidth=3,marker='o',
        markerfacecolor='red',markersize=7)
plt.xticks(np.arange(0,61,5),fontsize=15)
plt.yticks(np.arange(-35,35,10),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Thời gian khảo sát (60 phút)',fontsize=15)
plt.ylabel('Delta E(Wh)',fontsize=15)
plt.axhline(y=0,color='black',linewidth=3)
plt.grid()
plt.show()

# %% [markdown]
# # Tổng kết

# %%
mean_P_inv = []
mean_P_inv.append(data_inv_20_khaosat['P(W)'].mean())
mean_P_inv.append(data_inv_23_khaosat['P(W)'].mean())
mean_P_inv.append(data_inv_25_khaosat.iloc[:60]['P(W)'].mean())
mean_P_inv.append(data_inv_27_khaosat['P(W)'].mean())

mean_P_mono = []
mean_P_mono.append(data_mono_20_khaosat['P(W)'].mean())
mean_P_mono.append(data_mono_23_khaosat['P(W)'].mean())
mean_P_mono.append(data_mono_25_khaosat.iloc[:60]['P(W)'].mean())
mean_P_mono.append(data_mono_27_khaosat['P(W)'].mean())


plt.figure(figsize=(10,5))
plt.plot(mean_P_inv,color='blue',linewidth=3,marker='*',markersize=20,markerfacecolor='yellow',label='Công suất tác dụng trung bình máy lạnh Inverter')
plt.plot(mean_P_mono,color='red',linewidth=3,marker='*',markersize=20,markerfacecolor='yellow',label='Công suất tác dụng trung bình máy lạnh Non-Inverter')
plt.xticks(np.arange(4),['20','23','25','27'],fontsize=15)
plt.yticks(np.arange(0,750,100),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Nhiệt độ phòng cài đặt (độ C)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.grid()
plt.show()
mean_P_mono
# Out:
# [733.0851833333329, 651.8429005499999, 466.15227699999997, 191.2725237833333]

# %%
mean_E_inv = []
mean_E_inv.append(data_inv_20_khaosat['E(Wh)'].iloc[-1])
mean_E_inv.append(data_inv_23_khaosat['E(Wh)'].iloc[-1])
mean_E_inv.append(data_inv_25_khaosat.iloc[:60]['E(kWh)'].iloc[-1]*1000)
mean_E_inv.append(data_inv_27_khaosat['E(kWh)'].iloc[-1]*1000)

mean_E_mono = []
mean_E_mono.append(data_mono_20_khaosat['E(Wh)'].iloc[-1])
mean_E_mono.append(data_mono_23_khaosat['E(kWh)'].iloc[-1]*1000)
mean_E_mono.append(data_mono_25_khaosat.iloc[:60]['E(kWh)'].iloc[-1]*1000)
mean_E_mono.append(data_mono_27_khaosat['E(kWh)'].iloc[-1]*1000)

plt.figure(figsize=(10,5))
plt.plot(mean_E_inv,color='blue',linewidth=3,marker='*',markersize=20,markerfacecolor='yellow',label='Điện năng tiểu thụ của máy lạnh Inverter')
plt.plot(mean_E_mono,color='red',linewidth=3,marker='*',markersize=20,markerfacecolor='yellow',label='Điện năng tiêu thụ của máy lạnh Non-Inverter')
plt.xticks(np.arange(4),['20','23','25','27'],fontsize=15)
plt.yticks(np.arange(0,750,100),fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.xlabel('Nhiệt độ phòng cài đặt (độ C)',fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.grid()
plt.show()

# %%
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center',fontsize=15)

time_energy_efficiency = [48,37,33]
plt.figure(figsize=(10,5))
plt.bar(np.arange(3),time_energy_efficiency,label='Thời gian cần để máy lạnh Inverter' + '\n hiểu quả về điện năng so với Non-Inverter')
plt.xticks(np.arange(3),[23,25,27],fontsize=15)
plt.yticks(np.arange(0,80,10),fontsize=15)
plt.xlabel('Nhiệt độ phòng cài đặt',fontsize=15)
plt.ylabel('Thời gian (phút)',fontsize=15)
plt.legend(loc='best',fontsize=15)

addlabels([23,25,27],time_energy_efficiency)
plt.show()

# %%
khaosat_2h_25_inv = []
khaosat_2h_25_inv.append(data_inv_25_khaosat.iloc[59]['E(kWh)'])
khaosat_2h_25_inv.append(data_inv_25_khaosat.iloc[-1]['E(kWh)'])
khaosat_2h_25_inv = np.array(khaosat_2h_25_inv)*1000

khaosat_2h_25_mono = []
khaosat_2h_25_mono.append(data_mono_25_khaosat.iloc[59]['E(kWh)'])
khaosat_2h_25_mono.append(data_mono_25_khaosat.iloc[-1]['E(kWh)'])
khaosat_2h_25_mono = np.array(khaosat_2h_25_mono)*1000

plt.figure(figsize=(8,4))
plt.bar(np.arange(2),khaosat_2h_25_mono,color='red',width=0.4,label='Máy lạnh Non-Inverter')
plt.bar(np.arange(2),khaosat_2h_25_inv,color='blue',width=0.4,label='Máy lạnh Inverter')
plt.xticks(np.arange(2),['1 giờ','2 giờ'],fontsize=15)
plt.xlabel('Thời gian khảo sát',fontsize=15)
plt.yticks(np.arange(0,900,100),fontsize=15)
plt.ylabel('E(Wh)',fontsize=15)
plt.legend(loc='best',fontsize=15)
plt.show()

# %%
efficiency_percent = (khaosat_2h_25_mono - khaosat_2h_25_inv)/khaosat_2h_25_mono
efficiency_percent
# Out:
# array([0.11349036, 0.13207547])

# %% [markdown]
# # Khảo sát 15 phút đầu

# %%
firsttime_15m_20 = data_inv_20_khaosat[3:18]['P(W)'].mean()
firsttime_15m_23 = data_inv_23_khaosat[3:18]['P(W)'].mean()
firsttime_15m_25 = data_inv_25_khaosat[3:18]['P(W)'].mean()
firsttime_15m_27 = data_inv_27_khaosat[3:18]['P(W)'].mean()
firsttime_15m = np.array([firsttime_15m_20,firsttime_15m_23,firsttime_15m_25,firsttime_15m_27])
firsttime_15m
# Out:
# array([793.04177333, 766.74561333, 663.49828   , 209.56736667])

# %%
plt.figure(figsize=(8,4))
plt.bar(np.arange(4),firsttime_15m,width=0.8,label='Công suất tác dụng trung bình trong 15 phút đầu')
plt.xticks(np.arange(4),['20','23','25','27'],fontsize=15)
plt.yticks(np.arange(200,1200,200),fontsize=15)
plt.xlabel('Nhiệt độ phòng cài đặt (độ C)',fontsize=15)
plt.ylabel('P(W)',fontsize=15)
plt.legend(loc='best',fontsize=13)

addlabels(['20','23','25','27'],firsttime_15m.round(2))
plt.show()

# %%
data_inv_23['E(Wh)'].max()*10
# Out:
# 7195.696279
